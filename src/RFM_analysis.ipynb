# %%
import pandas as pd
import matplotlib.pyplot as plt
from datetime import datetime as dt, timedelta
import plotly.express as px
import seaborn as sns
import plotly.colors as pc
from ETL_pipeline import file_path
df = pd.read_csv(file_path)
df
# Out:
# Programm connected to DB succesfully
# Succesfully read dataset
# Data cleaned successfully
# Cleaned data uploaded to PostgreSQL succesfully
# ETL-pipeline has succesfully finished!
#       Row ID        Order ID  Order Date   Ship Date       Ship Mode  \
# 0          1  CA-2017-152156  2017-11-08  2017-11-11    Second Class
# 1          2  CA-2017-152156  2017-11-08  2017-11-11    Second Class
# 2          3  CA-2017-138688  2017-06-12  2017-06-16    Second Class
# 3          4  US-2016-108966  2016-10-11  2016-10-18  Standard Class
# 4          5  US-2016-108966  2016-10-11  2016-10-18  Standard Class
# ...      ...             ...         ...         ...             ...
# 9989    9990  CA-2015-110422  2015-01-21  2015-01-23    Second Class
# 9990    9991  CA-2018-121258  2018-02-26  2018-03-03  Standard Class
# 9991    9992  CA-2018-121258  2018-02-26  2018-03-03  Standard Class
# 9992    9993  CA-2018-121258  2018-02-26  2018-03-03  Standard Class
# ...

# %%
df.head()
# Out:
#    Row ID        Order ID  Order Date   Ship Date       Ship Mode Customer ID  \
# 0       1  CA-2017-152156  2017-11-08  2017-11-11    Second Class    CG-12520
# 1       2  CA-2017-152156  2017-11-08  2017-11-11    Second Class    CG-12520
# 2       3  CA-2017-138688  2017-06-12  2017-06-16    Second Class    DV-13045
# 3       4  US-2016-108966  2016-10-11  2016-10-18  Standard Class    SO-20335
# 4       5  US-2016-108966  2016-10-11  2016-10-18  Standard Class    SO-20335
#
#      Customer Name    Segment        Country             City  ...  \
# 0      Claire Gute   Consumer  United States        Henderson  ...
# 1      Claire Gute   Consumer  United States        Henderson  ...
# 2  Darrin Van Huff  Corporate  United States      Los Angeles  ...
# 3   Sean O'Donnell   Consumer  United States  Fort Lauderdale  ...
# 4   Sean O'Donnell   Consumer  United States  Fort Lauderdale  ...
#
#   Postal Code  Region       Product ID         Category Sub-Category  \
# ...

# %%
df.tail()
# Out:
#       Row ID        Order ID  Order Date   Ship Date       Ship Mode  \
# 9989    9990  CA-2015-110422  2015-01-21  2015-01-23    Second Class
# 9990    9991  CA-2018-121258  2018-02-26  2018-03-03  Standard Class
# 9991    9992  CA-2018-121258  2018-02-26  2018-03-03  Standard Class
# 9992    9993  CA-2018-121258  2018-02-26  2018-03-03  Standard Class
# 9993    9994  CA-2018-119914  2018-05-04  2018-05-09    Second Class
#
#      Customer ID     Customer Name   Segment        Country         City  ...  \
# 9989    TB-21400  Tom Boeckenhauer  Consumer  United States        Miami  ...
# 9990    DB-13060       Dave Brooks  Consumer  United States   Costa Mesa  ...
# 9991    DB-13060       Dave Brooks  Consumer  United States   Costa Mesa  ...
# 9992    DB-13060       Dave Brooks  Consumer  United States   Costa Mesa  ...
# 9993    CC-12220      Chris Cortes  Consumer  United States  Westminster  ...
#
#      Postal Code  Region       Product ID         Category Sub-Category  \
# ...

# %%
df['Order Date'] = pd.to_datetime(df['Order Date'])
df
# Out:
#       Row ID        Order ID Order Date   Ship Date       Ship Mode  \
# 0          1  CA-2017-152156 2017-11-08  2017-11-11    Second Class
# 1          2  CA-2017-152156 2017-11-08  2017-11-11    Second Class
# 2          3  CA-2017-138688 2017-06-12  2017-06-16    Second Class
# 3          4  US-2016-108966 2016-10-11  2016-10-18  Standard Class
# 4          5  US-2016-108966 2016-10-11  2016-10-18  Standard Class
# ...      ...             ...        ...         ...             ...
# 9989    9990  CA-2015-110422 2015-01-21  2015-01-23    Second Class
# 9990    9991  CA-2018-121258 2018-02-26  2018-03-03  Standard Class
# 9991    9992  CA-2018-121258 2018-02-26  2018-03-03  Standard Class
# 9992    9993  CA-2018-121258 2018-02-26  2018-03-03  Standard Class
# 9993    9994  CA-2018-119914 2018-05-04  2018-05-09    Second Class
#
#      Customer ID     Customer Name    Segment        Country             City  \
# ...

# %%
sorted_df = df.sort_values(by='Order Date', ascending=True)
sorted_df
# Out:
#       Row ID        Order ID Order Date   Ship Date       Ship Mode  \
# 7980    7981  CA-2015-103800 2015-01-03  2015-01-07  Standard Class
# 739      740  CA-2015-112326 2015-01-04  2015-01-08  Standard Class
# 740      741  CA-2015-112326 2015-01-04  2015-01-08  Standard Class
# 741      742  CA-2015-112326 2015-01-04  2015-01-08  Standard Class
# 1759    1760  CA-2015-141817 2015-01-05  2015-01-12  Standard Class
# ...      ...             ...        ...         ...             ...
# 5091    5092  CA-2018-156720 2018-12-30  2019-01-03  Standard Class
# 908      909  CA-2018-143259 2018-12-30  2019-01-03  Standard Class
# 907      908  CA-2018-143259 2018-12-30  2019-01-03  Standard Class
# 1296    1297  CA-2018-115427 2018-12-30  2019-01-03  Standard Class
# 906      907  CA-2018-143259 2018-12-30  2019-01-03  Standard Class
#
#      Customer ID      Customer Name      Segment        Country  \
# 7980    DP-13000      Darren Powers     Consumer  United States
# ...

# %%
reference_date = df['Order Date'].max() + timedelta(days=1)
reference_date
# Out:
# Timestamp('2018-12-31 00:00:00')

# %%
rfm_df = df.groupby('Customer ID').agg({
    'Order Date' : lambda x: (reference_date - x.max()).days,
    'Order ID' : 'count',
    'Sales' : 'sum'
}).reset_index()
rfm_df.tail()
# Out:
#     Customer ID  Order Date  Order ID     Sales
# 788    XP-21865          44        28  2374.658
# 789    YC-21895           5         8  5454.350
# 790    YS-21880          10        12  6720.444
# 791    ZC-21910          55        31  8025.707
# 792    ZD-21925         203         9  1493.944

# %%
rfm_df_m = rfm_df.rename(columns={'Order Date':'Recency', 'Order ID':'Frequency', 'Sales':'Monetary'})
rfm_df_m
# Out:
#     Customer ID  Recency  Frequency  Monetary
# 0      AA-10315      185         11  5563.560
# 1      AA-10375       20         15  1056.390
# 2      AA-10480      260         12  1790.512
# 3      AA-10645       56         18  5086.935
# 4      AB-10015      416          6   886.156
# ..          ...      ...        ...       ...
# 788    XP-21865       44         28  2374.658
# 789    YC-21895        5          8  5454.350
# 790    YS-21880       10         12  6720.444
# 791    ZC-21910       55         31  8025.707
# 792    ZD-21925      203          9  1493.944
#
# [793 rows x 4 columns]

# %%
Quantiles = rfm_df_m[['Recency', 'Frequency', 'Monetary']].quantile([0.25, 0.5, 0.75, 1])
Quantiles
# Out:
#       Recency  Frequency   Monetary
# 0.25     31.0        8.0   1146.050
# 0.50     76.0       12.0   2256.394
# 0.75    184.0       16.0   3785.276
# 1.00   1166.0       37.0  25043.050

# %%
q1_recency = rfm_df_m['Recency'].quantile(0.25)
q2_recency = rfm_df_m['Recency'].quantile(0.5)
q3_recency = rfm_df_m['Recency'].quantile(0.75)

def r_score(x):
    if x <= q1_recency:
        return 4
    elif x > q1_recency and x <= q2_recency:
        return 3
    elif x > q2_recency and x <= q3_recency:
        return 2
    else:
        return 1

rfm_df_m['R'] = rfm_df_m['Recency'].apply(r_score)

# %%
q1_frequency = rfm_df_m['Frequency'].quantile(0.25)
q2_frequency = rfm_df_m['Frequency'].quantile(0.5)
q3_frequency = rfm_df_m['Frequency'].quantile(0.75)

def f_score(x):
    if x <= q1_frequency:
        return 1
    elif x > q1_frequency and x <= q2_frequency:
        return 2
    elif x > q2_frequency and x <= q3_frequency:
        return 3
    else:
        return 4

rfm_df_m['F'] = rfm_df_m['Frequency'].apply(f_score)

# %%
q1_monetary = rfm_df_m['Monetary'].quantile(0.25)
q2_monetary = rfm_df_m['Monetary'].quantile(0.5)
q3_monetary = rfm_df_m['Monetary'].quantile(0.75)

def m_score(x):
    if x <= q1_monetary:
        return 1
    elif x > q1_monetary and x <= q2_monetary:
        return 2
    elif x > q2_monetary and x <= q3_monetary:
        return 3
    else:
        return 4
rfm_df_m['M'] = rfm_df_m['Monetary'].apply(m_score)

# %%
rfm_df_m
# Out:
#     Customer ID  Recency  Frequency  Monetary  R  F  M
# 0      AA-10315      185         11  5563.560  1  2  4
# 1      AA-10375       20         15  1056.390  4  3  1
# 2      AA-10480      260         12  1790.512  1  2  2
# 3      AA-10645       56         18  5086.935  3  4  4
# 4      AB-10015      416          6   886.156  1  1  1
# ..          ...      ...        ...       ... .. .. ..
# 788    XP-21865       44         28  2374.658  3  4  3
# 789    YC-21895        5          8  5454.350  4  1  4
# 790    YS-21880       10         12  6720.444  4  2  4
# 791    ZC-21910       55         31  8025.707  3  4  4
# 792    ZD-21925      203          9  1493.944  1  2  2
#
# [793 rows x 7 columns]

# %%
rfm_df_m['RFM_Segment']=rfm_df_m['R'].astype(str) + rfm_df_m['F'].astype(str) + rfm_df_m['M'].astype(str)

# %%
rfm_df_m['RFM_Score'] = rfm_df_m['R'] + rfm_df_m['F'] + rfm_df_m['M']
rfm_df_m
# Out:
#     Customer ID  Recency  Frequency  Monetary  R  F  M RFM_Segment  RFM_Score
# 0      AA-10315      185         11  5563.560  1  2  4         124          7
# 1      AA-10375       20         15  1056.390  4  3  1         431          8
# 2      AA-10480      260         12  1790.512  1  2  2         122          5
# 3      AA-10645       56         18  5086.935  3  4  4         344         11
# 4      AB-10015      416          6   886.156  1  1  1         111          3
# ..          ...      ...        ...       ... .. .. ..         ...        ...
# 788    XP-21865       44         28  2374.658  3  4  3         343         10
# 789    YC-21895        5          8  5454.350  4  1  4         414          9
# 790    YS-21880       10         12  6720.444  4  2  4         424         10
# 791    ZC-21910       55         31  8025.707  3  4  4         344         11
# 792    ZD-21925      203          9  1493.944  1  2  2         122          5
#
# [793 rows x 9 columns]

# %%
import numpy as np
def seqmentation(x):
    if x == '444':
        return 'VIP Client'
    elif x in ['344', '434', '443', '433', '343', '334', '333']:
        return 'High-Tier Loyal Customer'
    elif x in ['331', '332', '342', '341', '431', '432', '441', '442']:
        return 'Loyal Customer'
    elif x in ['424', '423', '422', '421', '324', '323', '322', '321']:
        return 'Potential Loyal Customers'
    elif x in ['314', '313', '312', '311', '244', '243', '242', '241', '234', '233', '232', '231', '224', '223', '222', '221']:
        return 'At Risk'
    elif x in ['214', '213', '212', '211', '144', '143', '142', '141',  '134', '133', '132', '131', '124', '123', '122', '121', '114', '113', '112', '111']:
        return 'Lost Client'
    elif x in ['411', '412', '413', '414']:
        return 'New Customer'
        
rfm_df_m['Customer_Category'] = rfm_df_m['RFM_Segment'].apply(seqmentation)

# %%
rfm_df_m
# Out:
#     Customer ID  Recency  Frequency  Monetary  R  F  M RFM_Segment  RFM_Score  \
# 0      AA-10315      185         11  5563.560  1  2  4         124          7
# 1      AA-10375       20         15  1056.390  4  3  1         431          8
# 2      AA-10480      260         12  1790.512  1  2  2         122          5
# 3      AA-10645       56         18  5086.935  3  4  4         344         11
# 4      AB-10015      416          6   886.156  1  1  1         111          3
# ..          ...      ...        ...       ... .. .. ..         ...        ...
# 788    XP-21865       44         28  2374.658  3  4  3         343         10
# 789    YC-21895        5          8  5454.350  4  1  4         414          9
# 790    YS-21880       10         12  6720.444  4  2  4         424         10
# 791    ZC-21910       55         31  8025.707  3  4  4         344         11
# 792    ZD-21925      203          9  1493.944  1  2  2         122          5
#
#              Customer_Category
# ...

# %%
rfm_df_m.to_csv('rfm_analysis_Superstore_sales.csv')

# %%
category_counts = rfm_df_m['Customer_Category'].value_counts().reset_index()
category_counts.columns = ['Customer_Category', 'Count']
category_counts = category_counts.sort_values(by='Customer_Category')

# %%
category_counts
# Out:
#            Customer_Category  Count
# 1                    At Risk    186
# 2   High-Tier Loyal Customer    149
# 0                Lost Client    251
# 4             Loyal Customer     39
# 5               New Customer     34
# 3  Potential Loyal Customers    105
# 6                 VIP Client     29

# %%
fig1 = px.bar(category_counts,
              x='Customer_Category', 
              y='Count', 
              title='Number of customers in each category',
             labels={'Customer_Category':'Customer Category', 'Count':'Count'},
             color='Customer_Category',
             color_discrete_sequence=px.colors.qualitative.Light24)
fig1.update_traces(textfont_size=10)
fig1.update_xaxes(tickangle=330)
fig1.show()

# %%
VIP_clients = rfm_df_m[rfm_df_m['RFM_Score'] == 12]
VIP_clients
# Out:
#     Customer ID  Recency  Frequency    Monetary  R  F  M RFM_Segment  \
# 35     AI-10855       14         18   4375.7860  4  4  4         444
# 65     BB-11545       29         20   6765.7280  4  4  4         444
# 82     BF-11170       17         27   5907.9720  4  4  4         444
# 88     BH-11710       24         24   6255.3510  4  4  4         444
# 130    CC-12220       21         22   3913.4180  4  4  4         444
# 215    DK-13225       11         19   4802.3940  4  4  4         444
# 233    DR-12880        4         24   6528.0340  4  4  4         444
# 275    EP-13915       13         31   5478.0608  4  4  4         444
# 278    ES-14080       29         20   4657.9240  4  4  4         444
# 328    HM-14860        3         20   8236.7648  4  4  4         444
# 365    JG-15160        2         18   6366.3920  4  4  4         444
# 387    JL-15835       22         34   9799.9230  4  4  4         444
# 430    KH-16510       23         23   5952.8590  4  4  4         444
# ...

# %%
corr_matrix = rfm_df_m[['R', 'F', 'M']].corr()

# %%
sns.heatmap(corr_matrix, annot=True, cmap='coolwarm', fmt='.2f')
plt.title('Correlation heatmap')
plt.show()

# %%
stat_by_category = rfm_df_m.groupby('Customer_Category').agg(total=('Monetary', 'sum'), median=('Monetary', 'median'))

# %%
only_total_by_c = stat_by_category[['Customer_Category', 'total']].reset_index()
only_total_by_c
# Out:
#    index          Customer_Category        total
# 0      0                    At Risk  576007.0584
# 1      1   High-Tier Loyal Customer  636936.3326
# 2      2                Lost Client  525544.6392
# 3      3             Loyal Customer   66427.2834
# 4      4               New Customer   41109.4238
# 5      5  Potential Loyal Customers  272410.3811
# 6      6                 VIP Client  178765.7418

# %%
fig2 = px.bar(only_total_by_c,
              x='Customer_Category', 
              y='total', 
              title='Total sales for each category',
             labels={'Customer_Category':'Customer Category', 'total':'Total'},
             color='Customer_Category',
             color_discrete_sequence=px.colors.qualitative.Set3)
fig2.update_traces(textfont_size=10)
fig2.update_xaxes(tickangle=330)
fig2.show()

# %%
only_median_by_c = stat_by_category[['Customer_Category', 'median']].reset_index()

# %%
fig2 = px.bar(only_median_by_c,
              x='Customer_Category', 
              y='median', 
              title='Median of sales for each category',
             labels={'Customer_Category':'Customer Category', 'median':'Median'},
             color='Customer_Category',
             color_discrete_sequence=px.colors.qualitative.Plotly)
fig2.update_traces(textfont_size=10)
fig2.update_xaxes(tickangle=330)
fig2.show()
